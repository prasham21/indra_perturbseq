# %%
import scanpy as sc
import pandas as pd
from indra.sources import indra_db_rest

# %%
adata_de = sc.read_h5ad("/Users/prashammarfatia/Downloads/adata_de_backup.h5ad")
target_validation_df = pd.read_csv("/Users/prashammarfatia/Downloads/target_validation.csv")

# %%
import pandas as pd
direct_pathway_results = pd.read_csv("/Users/prashammarfatia/Downloads/progressive_pathway_analysis.csv")

# Extract successful knockdown targets
successful_targets = target_validation_df[
    target_validation_df['Karen_Flag'] == 'Use_for_analysis'
]['Gene'].tolist()
